# %% [markdown]
# <a href="https://colab.research.google.com/github/Malihakhan03/Artificial-Intelligence/blob/main/Practical_09_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ML LAB-9
# AIM:-To implement the k means clustering algorithm and analyze the clustering results using appropriate evaluation techniques.
#
# Maliha Khan CS23054

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path="/content/drive/MyDrive/Datasets/Mall_Customers.csv" #REPLACE PATH ACCORING TO YOUR DATASET'S PATH
df = pd.read_csv(path)
df.head()

# %%
df.shape

# %%
df.describe()

# %%
df.info()

# %%
df.isnull().any()

# %%
df.isnull()

# %%
df

# %%
df.isnull().sum()

# %%
#only requied columns and only two column x have
x = df.iloc[:,[3,4]].values

# %%
x

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
#feature scaling
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
inertia_values = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k,random_state=42)
    kmeans.fit(x_scaled)
    inertia_values.append(kmeans.inertia_)

print(inertia_values)
#this step is to know the value of k by using elbow method

# %%
plt.figure()
plt.plot(range(1, 11),inertia_values, marker='o')
plt.xlabel('Number of Clusters(x)')
plt.ylabel('Inertia')
plt.title("Elbow Method for optimal k")
plt.show()
#where drastically change that is consider for k value

# %%
#step6: apply k-means(Assume k=5)
kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(x_scaled)

# add cluster labels
df['Cluster'] = clusters
print(df.head())

# %%
df

# %%
#silhoutte score use to check quality(more towards 1 more optimal)
#step 7 evaluate clustering
print("inertia:", kmeans.inertia_)

print("Silhouette Score:", silhouette_score(x_scaled, clusters))

# %%
#step8 visualize
plt.figure()
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=df, palette='Set1')

#plot centroid
centroids = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(centroids[:,0],
            centroids[:,1],
            s=200,
            c='black',marker='X',label='Centroids')

plt.title("Customer segmentation using K-means")
plt.legend()
plt.show()

# %%
#step6: apply k-means(Assume k=4)
kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(x_scaled)

# add cluster labels
df['Cluster'] = clusters
print(df.head())

# %%
#step 7 evaluate clustering
print("inertia:", kmeans.inertia_)

print("Silhouette Score:", silhouette_score(x_scaled, clusters))

# %%
#step6: apply k-means(Assume k=3)
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(x_scaled)
print("inertia:", kmeans.inertia_)

print("Silhouette Score:", silhouette_score(x_scaled, clusters))

# %%
#step6: apply k-means(Assume k=6)
kmeans = KMeans(n_clusters=6, random_state=42)
clusters = kmeans.fit_predict(x_scaled)
print("inertia:", kmeans.inertia_)

print("Silhouette Score:", silhouette_score(x_scaled, clusters))

# %%
#step6: apply k-means(Assume k=7)
kmeans = KMeans(n_clusters=7, random_state=42)
clusters = kmeans.fit_predict(x_scaled)
print("inertia:", kmeans.inertia_)

print("Silhouette Score:", silhouette_score(x_scaled, clusters))

# %%
#step6: apply k-means(Assume k=8)
kmeans = KMeans(n_clusters=8, random_state=42)
clusters = kmeans.fit_predict(x_scaled)
print("inertia:", kmeans.inertia_)

print("Silhouette Score:", silhouette_score(x_scaled, clusters))
